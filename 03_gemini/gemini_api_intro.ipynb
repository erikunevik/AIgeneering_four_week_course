# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain how AI works in a few words",
)

print(response.text)
# Out:
# AI learns patterns from data to make smart decisions or predictions.

# %%
def ask_gemini(prompt, model = "gemini-2.5-flash" ):
    response = client.models.generate_content(
        model=model,
        contents=prompt,
    )
    
    return response

response = ask_gemini("Can you give me 5 facts abt Luca Toni?")
print(response.text)
# Out:
# Here are 5 facts about Luca Toni:
#
# 1.  **World Cup Winner:** Luca Toni was a key part of the Italy squad that won the 2006 FIFA World Cup in Germany. He scored two goals in the tournament, both in the quarter-final match against Ukraine.
#
# 2.  **European Golden Shoe:** In the 2005-2006 season, while playing for Fiorentina, Toni won the European Golden Shoe as the top league goalscorer in Europe, scoring an impressive 31 goals in Serie A. He was the first Italian player ever to win the award.
#
# 3.  **Late Bloomer with Longevity:** Toni defied the odds by having one of his most prolific periods in his late 30s. He became the Serie A Capocannoniere (top scorer) again in the 2014-2015 season for Hellas Verona at the age of 38, making him the oldest player ever to win the award.
#
# 4.  **Bundesliga Success with Bayern Munich:** After his impressive spell at Fiorentina, Toni moved to Bayern Munich in 2007. He immediately made an impact, becoming the top scorer in the Bundesliga in his debut season (2007-2008) with 24 goals, helping Bayern win the league and cup double.
#
# 5.  **Iconic Goal Celebration:** Toni was famous for his distinctive goal celebration, where he would twist his hand by his ear, often described as "turning the screw" or "turning the key." This became his trademark gesture throughout his career.

# %%
from pydantic import BaseModel


# Knows that it is a pydantic model
isinstance(response, BaseModel)
# Out:
# True

# %%
# response.__dict__

dict(response).keys()
# Out:
# dict_keys(['sdk_http_response', 'candidates', 'create_time', 'model_version', 'prompt_feedback', 'response_id', 'usage_metadata', 'automatic_function_calling_history', 'parsed'])

# %%
response.model_version
# Out:
# 'gemini-2.5-flash'

# %%
response.sdk_http_response
# Out:
# HttpResponse(
#   headers=<dict len=11>
# )

# %%
response.candidates
# Out:
# [Candidate(
#    content=Content(
#      parts=[
#        Part(
#          text="""Here are 5 facts about Luca Toni:
#
#  1.  **World Cup Winner:** Luca Toni was a key part of the Italy squad that won the 2006 FIFA World Cup in Germany. He scored two goals in the tournament, both in the quarter-final match against Ukraine.
#
#  2.  **European Golden Shoe:** In the 2005-2006 season, while playing for Fiorentina, Toni won the European Golden Shoe as the top league goalscorer in Europe, scoring an impressive 31 goals in Serie A. He was the first Italian player ever to win the award.
#
#  3.  **Late Bloomer with Longevity:** Toni defied the odds by having one of his most prolific periods in his late 30s. He became the Serie A Capocannoniere (top scorer) again in the 2014-2015 season for Hellas Verona at the age of 38, making him the oldest player ever to win the award.
#
#  4.  **Bundesliga Success with Bayern Munich:** After his impressive spell at Fiorentina, Toni moved to Bayern Munich in 2007. He immediately made an impact, becoming the top scorer in the Bundesliga in his debut season (2007-2008) with 24 goals, helping Bayern win the league and cup double.
#
#  5.  **Iconic Goal Celebration:** Toni was famous for his distinctive goal celebration, where he would twist his hand by his ear, often described as "turning the screw" or "turning the key." This became his trademark gesture throughout his career."""
#        ),
#      ],
#      role='model'
#    ),
#    finish_reason=<FinishReason.STOP: 'STOP'>,
#    index=0
#  )]

# %%
response.text
# Out:
# 'Here are 5 facts about Luca Toni:\n\n1.  **World Cup Winner:** Luca Toni was a key part of the Italy squad that won the 2006 FIFA World Cup in Germany. He scored two goals in the tournament, both in the quarter-final match against Ukraine.\n\n2.  **European Golden Shoe:** In the 2005-2006 season, while playing for Fiorentina, Toni won the European Golden Shoe as the top league goalscorer in Europe, scoring an impressive 31 goals in Serie A. He was the first Italian player ever to win the award.\n\n3.  **Late Bloomer with Longevity:** Toni defied the odds by having one of his most prolific periods in his late 30s. He became the Serie A Capocannoniere (top scorer) again in the 2014-2015 season for Hellas Verona at the age of 38, making him the oldest player ever to win the award.\n\n4.  **Bundesliga Success with Bayern Munich:** After his impressive spell at Fiorentina, Toni moved to Bayern Munich in 2007. He immediately made an impact, becoming the top scorer in the Bundesliga in his debut season (2007-2008) with 24 goals, helping Bayern win the league and cup double.\n\n5.  **Iconic Goal Celebration:** Toni was famous for his distinctive goal celebration, where he would twist his hand by his ear, often described as "turning the screw" or "turning the key." This became his trademark gesture throughout his career.'

# %%
response.usage_metadata
# Out:
# GenerateContentResponseUsageMetadata(
#   candidates_token_count=337,
#   prompt_token_count=13,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=13
#     ),
#   ],
#   thoughts_token_count=788,
#   total_token_count=1138
# )
