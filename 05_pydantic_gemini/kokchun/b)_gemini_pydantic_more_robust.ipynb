# %% [markdown]
# # Structure gemini outputs with Pydantic

# %%
from google import genai
from pydantic import BaseModel

class Recipe(BaseModel):
    recipe_name: str 
    description: str
    ingredients: list[str]

client = genai.Client()

response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients",
)

print(response.text)
# Out:
# Here are a few delectable Asian soup recipes, complete with a yummy description and key ingredients!
#
# ---
#
# ### 1. Vietnamese Pho Bo (Beef Noodle Soup)
#
# **Yummy Description:** Imagine a deeply aromatic and utterly soul-satisfying bowl, brimming with a broth that's been slow-simmered for hours with charred onions, ginger, and a symphony of warm spices like star anise, cloves, and cinnamon. This fragrant elixir cradles tender, thinly sliced beef and delicate rice noodles, ready to be adorned with a vibrant confetti of fresh herbs like basil, mint, and cilantro, crunchy bean sprouts, a squeeze of lime, and a fiery slice of jalapeño. It's a comforting, complex, and incredibly fresh culinary masterpiece.
#
# **Key Ingredients:**
#
# *   **Broth Base:** Beef bones (marrow and knuckle), beef flank or brisket, onions, ginger, star anise, cinnamon sticks, black cardamom pods, cloves, coriander seeds, rock sugar, fish sauce.
# *   **Noodles:** Flat rice noodles (Bánh Phở).
# *   **Protein:** Thinly sliced raw beef (eye of round or sirloin), cooked beef (brisket or flank, if used in broth).
# *   **Garnishes:** Fresh bean sprouts, Thai basil, mint leaves, cilantro, lime wedges, sliced jalapeños or bird's eye chilies, hoisin sauce, Sriracha.
#
# ---
#
# ### 2. Thai Tom Yum Goong (Spicy Shrimp Soup)
#
# **Yummy Description:** Brace your taste buds for an explosion of vibrant Thai flavors! This iconic hot and sour soup is a tantalizing dance between fiery chili heat, tangy lime juice, and the rich umami of shrimp. The clear, fragrant broth is infused with the irresistible aroma of lemongrass, galangal (Thai ginger), and kaffir lime leaves, creating a symphony that is simultaneously spicy, sour, salty, and a little sweet. Plump, juicy shrimp and tender mushrooms swim in this exhilarating elixir, making every spoonful an adventure.
#
# **Key Ingredients:**
#
# *   **Broth Base:** Chicken or vegetable broth (or water), fresh shrimp heads/shells (optional, for extra flavor), lemongrass stalks, galangal, kaffir lime leaves.
# *   **Protein:** Fresh large shrimp.
# *   **Vegetables:** Straw mushrooms or oyster mushrooms, cherry tomatoes (optional).
# *   **Seasoning:** Fish sauce, fresh lime juice, Thai bird's eye chilies (fresh or chili paste/Nam Prik Pao), a pinch of sugar.
# *   **Garnish:** Fresh cilantro.
#
# ---
#
# ### 3. Japanese Shoyu Ramen (Soy Sauce Ramen)
#
# **Yummy Description:** Imagine diving into a big, steamy bowl of pure comfort! Shoyu Ramen features a clear, savory chicken or pork broth deeply flavored with soy sauce, creating a rich yet balanced umami bomb. It's perfectly paired with springy, chewy ramen noodles that soak up all that deliciousness. Crowned with tender slices of melt-in-your-mouth chashu pork, a perfectly jammy soft-boiled egg (ajitama), crisp bamboo shoots, and bright green scallions, it's a symphony of textures and flavors that will warm you from the inside out.
#
# **Key Ingredients:**
#
# *   **Broth (Chintan):** Chicken carcass (or pork bones), dried shiitake mushrooms, kombu, green onions, ginger.
# *   **Tare (Flavoring Concentrate):** Soy sauce, mirin, sake, a dash of dashi or broth.
# *   **Noodles:** Fresh ramen noodles.
# *   **Toppings:**
#     *   **Chashu:** Braised pork belly or shoulder.
#     *   **Ajitama:** Marinated soft-boiled egg.
#     *   **Menma:** Seasoned bamboo shoots.
#     *   **Nori:** Dried seaweed.
#     *   **Scallions:** Chopped green onions.
#     *   **Narutomaki:** Fish cake (optional).
#
# ---
#
# ### 4. Chinese Wonton Noodle Soup
#
# **Yummy Description:** This is classic Chinese comfort in a bowl! Delicate, silken wontons, plump with a savory filling of seasoned pork and shrimp, float gracefully in a light yet incredibly flavorful clear broth. Paired with slender, springy egg noodles and often accompanied by crisp green leafy vegetables, every spoonful offers a delightful contrast of textures and a comforting, wholesome taste. It's simple elegance that warms the soul and satisfies the palate.
#
# **Key Ingredients:**
#
# *   **Wontons:**
#     *   **Filling:** Ground pork, finely chopped shrimp, ginger, green onions, soy sauce, sesame oil, white pepper, cornstarch.
#     *   **Wrapper:** Wonton wrappers.
# *   **Broth:** Chicken broth (homemade or good quality store-bought), soy sauce, sesame oil, white pepper, salt to taste.
# *   **Noodles:** Thin egg noodles (wonton noodles).
# *   **Vegetables (Optional):** Bok choy, gai lan (Chinese broccoli).
# *   **Garnish:** Chopped green onions.

# %%
response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents = "List a few asian soups recipes, a yummy description and list the ingredients",
    config = {"response_mime_type": "application/json", "response_schema": list[Recipe]}
)

print(response.text)
# Out:
# [
#   {
#     "recipe_name": "Tom Yum Goong",
#     "description": "A vibrant and intensely flavorful Thai hot and sour shrimp soup, brimming with aromatic lemongrass, galangal, kaffir lime leaves, and a spicy kick that awakens the senses. It's a delightful balance of tangy, spicy, and savory.",
#     "ingredients": [
#       "Shrimp",
#       "Lemongrass stalks",
#       "Galangal slices",
#       "Kaffir lime leaves",
#       "Mushrooms",
#       "Cherry tomatoes",
#       "Fish sauce",
#       "Lime juice",
#       "Thai chili paste (nam prik pao)",
#       "Cilantro"
#     ]
#   },
#   {
#     "recipe_name": "Classic Miso Soup",
#     "description": "A comforting and wholesome Japanese soup, featuring a delicate dashi broth infused with savory miso paste, soft cubes of tofu, and tender wakame seaweed. It's the quintessential umami-rich start to any meal.",
#     "ingredients": [
#       "Dashi stock",
#       "Miso paste (white or red)",
#       "Silken tofu",
#       "Dried wakame seaweed",
#       "Green onions"
#     ]
#   },
#   {
#     "recipe_name": "Pho Bo (Vietnamese Beef Noodle Soup)",
#     "description": "A deeply aromatic and soul-warming Vietnamese beef noodle soup, celebrated for its complex, slow-simmered broth, tender slices of beef, slippery rice noodles, and a vibrant medley of fresh herbs and sprouts. Each spoonful is a journey of flavor.",
#     "ingredients": [
#       "Beef bones",
#       "Flank steak or brisket",
#       "Rice noodles",
#       "Star anise",
#       "Cinnamon sticks",
#       "Cloves",
#       "Black cardamom pods",
#       "Ginger",
#       "Onions",
#       "Fish sauce",
#       "Bean sprouts",
#       "Thai basil",
#       "Cilantro",
#       "Lime wedges",
#       "Jalapeños"
#     ]
#   }
# ]

# %%
recipes = response.parsed
recipes
# Out:
# [Recipe(recipe_name='Tom Yum Goong', description="A vibrant and intensely flavorful Thai hot and sour shrimp soup, brimming with aromatic lemongrass, galangal, kaffir lime leaves, and a spicy kick that awakens the senses. It's a delightful balance of tangy, spicy, and savory.", ingredients=['Shrimp', 'Lemongrass stalks', 'Galangal slices', 'Kaffir lime leaves', 'Mushrooms', 'Cherry tomatoes', 'Fish sauce', 'Lime juice', 'Thai chili paste (nam prik pao)', 'Cilantro']),
#  Recipe(recipe_name='Classic Miso Soup', description="A comforting and wholesome Japanese soup, featuring a delicate dashi broth infused with savory miso paste, soft cubes of tofu, and tender wakame seaweed. It's the quintessential umami-rich start to any meal.", ingredients=['Dashi stock', 'Miso paste (white or red)', 'Silken tofu', 'Dried wakame seaweed', 'Green onions']),
#  Recipe(recipe_name='Pho Bo (Vietnamese Beef Noodle Soup)', description='A deeply aromatic and soul-warming Vietnamese beef noodle soup, celebrated for its complex, slow-simmered broth, tender slices of beef, slippery rice noodles, and a vibrant medley of fresh herbs and sprouts. Each spoonful is a journey of flavor.', ingredients=['Beef bones', 'Flank steak or brisket', 'Rice noodles', 'Star anise', 'Cinnamon sticks', 'Cloves', 'Black cardamom pods', 'Ginger', 'Onions', 'Fish sauce', 'Bean sprouts', 'Thai basil', 'Cilantro', 'Lime wedges', 'Jalapeños'])]

# %%
recipes[0].description, recipes[0].recipe_name, recipes[0].ingredients
# Out:
# ("A vibrant and intensely flavorful Thai hot and sour shrimp soup, brimming with aromatic lemongrass, galangal, kaffir lime leaves, and a spicy kick that awakens the senses. It's a delightful balance of tangy, spicy, and savory.",
#  'Tom Yum Goong',
#  ['Shrimp',
#   'Lemongrass stalks',
#   'Galangal slices',
#   'Kaffir lime leaves',
#   'Mushrooms',
#   'Cherry tomatoes',
#   'Fish sauce',
#   'Lime juice',
#   'Thai chili paste (nam prik pao)',
#   'Cilantro'])

# %% [markdown]
# ## simulate house prices

# %%
from typing import Literal

class Home(BaseModel):
    price: int 
    monthly_fee: int
    living_area: float 
    number_rooms: int 
    type: Literal["apartment", "house"]
    address: str 



response = client.models.generate_content(
    model = "gemini-2.5-pro",
    contents = """List 50 apartments and houses in Sweden with their monthly_fee, their price, living area, 
    number of rooms, address, type if it is apartment or house. 
    All currencies are in SEK.""",
    config = {"response_mime_type": "application/json", "response_schema": list[Home]}
)


homes = response.parsed
homes
# Out:
# [Home(price=2850000, monthly_fee=2100, living_area=32.5, number_rooms=1, type='apartment', address='Sveavägen 10A, 111 57 Stockholm'),
#  Home(price=5200000, monthly_fee=3500, living_area=125.0, number_rooms=5, type='house', address='Björkvägen 5, 416 52 Göteborg'),
#  Home(price=3100000, monthly_fee=4200, living_area=78.0, number_rooms=3, type='apartment', address='Drottninggatan 22, 211 41 Malmö'),
#  Home(price=7500000, monthly_fee=4500, living_area=180.0, number_rooms=7, type='house', address='Ekstigen 12, 756 51 Uppsala'),
#  Home(price=8900000, monthly_fee=5500, living_area=105.5, number_rooms=4, type='apartment', address='Hornsgatan 45B, 118 49 Stockholm'),
#  Home(price=4150000, monthly_fee=3100, living_area=112.0, number_rooms=4, type='house', address='Tallvägen 8, 582 73 Linköping'),
#  Home(price=3750000, monthly_fee=3300, living_area=58.0, number_rooms=2, type='apartment', address='Linnégatan 30, 413 04 Göteborg'),
#  Home(price=3950000, monthly_fee=2900, living_area=95.0, number_rooms=3, type='house', address='Strandgatan 15, 216 12 Limhamn'),
#  Home(price=2300000, monthly_fee=3900, living_area=68.5, number_rooms=3, type='apartment', address='Storgatan 50, 903 26 Umeå'),
#  Home(price=3100000, monthly_fee=4100, living_area=155.0, number_rooms=6, type='house', address='Fjällgatan 3, 981 39 Kiruna'),
#  Home(price=2995000, monthly_fee=1950, living_area=28.0, number_rooms=1, type='apartment', address='Odengatan 72, 113 22 Stockholm'),
#  Home(price=4800000, monthly_fee=3250, living_area=130.0, number_rooms=5, type='house', address='Kustvägen 44, 621 41 Visby'),
#  Home(price=7200000, monthly_fee=6800, living_area=122.0, number_rooms=5, type='apartment', address='Vasagatan 11, 411 24 Göteborg'),
#  Home(price=5800000, monthly_fee=3400, living_area=108.0, number_rooms=4, type='house', address='Klostergatan 9, 222 22 Lund'),
#  Home(price=2250000, monthly_fee=3100, living_area=52.5, number_rooms=2, type='apartment', address='Amiralsgatan 80, 214 37 Malmö'),
#  Home(price=4300000, monthly_fee=3900, living_area=165.0, number_rooms=6, type='house', address='Änggatan 21, 702 12 Örebro'),
#  Home(price=3600000, monthly_fee=4300, living_area=82.0, number_rooms=3, type='apartment', address='Svartbäcksgatan 18, 753 32 Uppsala'),
#  Home(price=4050000, monthly_fee=3150, living_area=118.0, number_rooms=5, type='house', address='Sjögatan 25, 553 16 Jönköping'),
#  Home(price=3850000, monthly_fee=5100, living_area=98.0, number_rooms=4, type='apartment', address='Drottninggatan 101, 252 21 Helsingborg'),
#  Home(price=5900000, monthly_fee=4900, living_area=205.0, number_rooms=7, type='house', address='Parkvägen 14, 723 48 Västerås'),
#  Home(price=12500000, monthly_fee=7800, living_area=145.0, number_rooms=5, type='apartment', address='Strandvägen 7C, 114 56 Stockholm'),
#  Home(price=4950000, monthly_fee=3000, living_area=99.0, number_rooms=4, type='house', address='Liljegatan 6, 431 39 Mölndal'),
#  Home(price=2950000, monthly_fee=3600, living_area=61.5, number_rooms=2, type='apartment', address='Ribersborgsvägen 1, 217 53 Malmö'),
#  Home(price=3700000, monthly_fee=3500, living_area=128.0, number_rooms=5, type='house', address='Kungsgatan 55, 602 33 Norrköping'),
#  Home(price=2550000, monthly_fee=4250, living_area=73.0, number_rooms=3, type='apartment', address='Kyrkogatan 19, 972 32 Luleå'),
#  Home(price=6200000, monthly_fee=4400, living_area=172.0, number_rooms=6, type='house', address='Prinsgatan 10, 302 46 Halmstad'),
#  Home(price=4800000, monthly_fee=2600, living_area=45.5, number_rooms=2, type='apartment', address='Drottninggatan 90, 111 36 Stockholm'),
#  Home(price=3300000, monthly_fee=2950, living_area=107.0, number_rooms=4, type='house', address='Solgatan 1, 652 25 Karlstad'),
#  Home(price=5750000, monthly_fee=4950, living_area=86.0, number_rooms=3, type='apartment', address='Avenyn 2, 411 36 Göteborg'),
#  Home(price=7800000, monthly_fee=3800, living_area=142.0, number_rooms=5, type='house', address='Adelsgatan 30, 621 57 Visby'),
#  Home(price=6950000, monthly_fee=6200, living_area=115.0, number_rooms=4, type='apartment', address='Dockgatan 5, 211 12 Malmö'),
#  Home(price=3500000, monthly_fee=3700, living_area=138.0, number_rooms=5, type='house', address='Villagatan 17, 803 24 Gävle'),
#  Home(price=1950000, monthly_fee=1750, living_area=24.0, number_rooms=1, type='apartment', address='Studentvägen 1, 752 34 Uppsala'),
#  Home(price=3800000, monthly_fee=4000, living_area=158.0, number_rooms=6, type='house', address='Druveforsvägen 8, 504 33 Borås'),
#  Home(price=2700000, monthly_fee=4050, living_area=71.0, number_rooms=3, type='apartment', address='Ågatan 23, 582 22 Linköping'),
#  Home(price=4400000, monthly_fee=3300, living_area=115.0, number_rooms=4, type='house', address='Stockholmsvägen 33, 152 40 Södertälje'),
#  Home(price=2000000, monthly_fee=3500, living_area=60.0, number_rooms=2, type='apartment', address='Storgatan 35, 352 31 Växjö'),
#  Home(price=3200000, monthly_fee=3400, living_area=122.0, number_rooms=5, type='house', address='Kungsgatan 1, 632 20 Eskilstuna'),
#  Home(price=5400000, monthly_fee=3100, living_area=51.5, number_rooms=2, type='apartment', address='Västerlånggatan 68, 111 29 Stockholm'),
#  Home(price=9800000, monthly_fee=4700, living_area=185.0, number_rooms=6, type='house', address='Rosenvägen 2, 183 54 Täby'),
#  Home(price=3300000, monthly_fee=2300, living_area=38.0, number_rooms=1, type='apartment', address='Östra Hamngatan 46, 411 09 Göteborg'),
#  Home(price=15500000, monthly_fee=5600, living_area=225.0, number_rooms=7, type='house', address='Sjövägen 1, 131 33 Nacka'),
#  Home(price=3550000, monthly_fee=4400, living_area=80.0, number_rooms=3, type='apartment', address='Långa Bryggan 10, 211 18 Malmö'),
#  Home(price=2900000, monthly_fee=3800, living_area=145.0, number_rooms=5, type='house', address='Esplanaden 14, 852 32 Sundsvall'),
#  Home(price=2400000, monthly_fee=3700, living_area=56.5, number_rooms=2, type='apartment', address='Rådhusesplanaden 12, 903 28 Umeå'),
#  Home(price=18900000, monthly_fee=6100, living_area=255.0, number_rooms=8, type='house', address='Norra Kungsvägen 22, 181 31 Lidingö'),
#  Home(price=3450000, monthly_fee=3900, living_area=64.0, number_rooms=2, type='apartment', address='Stora Södergatan 5, 222 23 Lund'),
#  Home(price=8400000, monthly_fee=4800, living_area=178.0, number_rooms=6, type='house', address='Oceanvägen 7, 252 25 Helsingborg'),
#  Home(price=6100000, monthly_fee=5000, living_area=90.5, number_rooms=3, type='apartment', address='Gustav III:s Boulevard 18, 169 73 Solna'),
#  Home(price=3650000, monthly_fee=4100, living_area=152.0, number_rooms=5, type='house', address='Stortorget 4, 831 30 Östersund')]

# %%
len(homes)
# Out:
# 50

# %%
import pandas as pd

df = pd.DataFrame([home.__dict__ for home in homes])
df.head()
# Out:
#      price  monthly_fee  living_area  number_rooms       type  \
# 0  2850000         2100         32.5             1  apartment
# 1  5200000         3500        125.0             5      house
# 2  3100000         4200         78.0             3  apartment
# 3  7500000         4500        180.0             7      house
# 4  8900000         5500        105.5             4  apartment
#
#                             address
# 0   Sveavägen 10A, 111 57 Stockholm
# 1     Björkvägen 5, 416 52 Göteborg
# 2   Drottninggatan 22, 211 41 Malmö
# 3       Ekstigen 12, 756 51 Uppsala
# 4  Hornsgatan 45B, 118 49 Stockholm

# %%
df.query("price < 3_000_000")
# Out:
#       price  monthly_fee  living_area  number_rooms       type  \
# 0   2850000         2100         32.5             1  apartment
# 8   2300000         3900         68.5             3  apartment
# 10  2995000         1950         28.0             1  apartment
# 14  2250000         3100         52.5             2  apartment
# 22  2950000         3600         61.5             2  apartment
# 24  2550000         4250         73.0             3  apartment
# 32  1950000         1750         24.0             1  apartment
# 34  2700000         4050         71.0             3  apartment
# 36  2000000         3500         60.0             2  apartment
# 43  2900000         3800        145.0             5      house
# 44  2400000         3700         56.5             2  apartment
#
#                              address
# 0    Sveavägen 10A, 111 57 Stockholm
# 8          Storgatan 50, 903 26 Umeå
# 10    Odengatan 72, 113 22 Stockholm
# 14     Amiralsgatan 80, 214 37 Malmö
# 22  Ribersborgsvägen 1, 217 53 Malmö
# 24       Kyrkogatan 19, 972 32 Luleå
# 32    Studentvägen 1, 752 34 Uppsala
# 34       Ågatan 23, 582 22 Linköping
# 36        Storgatan 35, 352 31 Växjö
# 43   Esplanaden 14, 852 32 Sundsvall
# 44  Rådhusesplanaden 12, 903 28 Umeå
