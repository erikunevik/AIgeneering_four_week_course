# %% [markdown]
# #0

# %% [markdown]
# ## a)

# %%
from pathlib import Path

import pandas as pd

data_dir = Path("../data")
files = sorted(data_dir.glob("ads*.txt"))

job_ads = []

for path in files:
    text = path.read_text(encoding="utf-8")
    job_ads.append(
        {
            
            "filename":path.name,
            "text": text,
         
         }
        
    )
    

df = pd.DataFrame(job_ads)
print(df)
# Out:
#    filename                                               text
# 0  ads1.txt  About the team\n\nThe Data Platform team is ne...
# 1  ads2.txt  Engineering Operations Technician , Data Cente...
# 2  ads3.txt  At NOBA Bank Group, we are unlocking new possi...
# 3  ads4.txt  Fysioterapeut/sjukgymnast till HSL-team inom L...

# %% [markdown]
# ##b

# %%
from google import genai

client = genai.Client()

def summarize_ads(df, model="gemini-2.5-flash"):
    def get_summary(ad_text):
        response = client.models.generate_content(
            model=model,
            contents=f"Summarize this job ad:{ad_text}"
        )
        return response.text
    
    df["summary"] = df["text"].apply(get_summary)
    return df

# Använd den
df = summarize_ads(df)

print(df.loc[0, "summary"])
# Out:
# This job ad is for a **Data Engineer with an interest in Analytics Engineering** at **Instabee**, a rapidly growing European last-mile delivery company (formed by Budbee and Instabox).
#
# The role is within a newly formed Data Platform team, tasked with building and shaping a modern data platform on GCP and Snowflake, utilizing tools like Fivetran, Python, DBT, and Tableau. This is a hybrid role, serving stakeholders across BI, data science, and product teams.
#
# **Key responsibilities include:**
#
# *   **Data Engineering:** Leading and building data source integrations (APIs, MongoDB, MySQL), setting up and maintaining data platform infrastructure, implementing CI/CD and IaC, orchestrating data pipelines (e.g., Airflow), and introducing data product principles.
# *   **Analytics Engineering:** Designing and building robust data models using DBT, SQL, and Python to support business processes, ensuring data governance and trust, and contributing to analytical projects.
#
# **They are looking for someone with:**
#
# *   Experience in both Data Engineering and Analytics Engineering.
# *   Proficiency in building modern data platforms with GCP and Snowflake.
# *   Skills in data modeling (DBT, SQL), programming (Python, Java, or Go), CI/CD, IaC, and data orchestration.
# *   A technical or analytical university degree.
# *   Strong collaboration, communication skills, an agile mindset, and a drive to learn.
# *   Based in Stockholm and open to hybrid work (3 days in the office).
# *   Experience with Docker, Kubernetes, and streaming data is a plus.
#
# **Instabee offers** a chance to revolutionize logistics, a modern "sky-high" office (puppy-friendly), tech events, games, flexible hours, parental pay, and a birthday off, all within a company committed to diversity and inclusion.

# %%
df["summary"][0]
# Out:
# 'This job ad is for a **Data Engineer with an interest in Analytics Engineering** at **Instabee**, a rapidly growing European last-mile delivery company (formed by Budbee and Instabox).\n\nThe role is within a newly formed Data Platform team, tasked with building and shaping a modern data platform on GCP and Snowflake, utilizing tools like Fivetran, Python, DBT, and Tableau. This is a hybrid role, serving stakeholders across BI, data science, and product teams.\n\n**Key responsibilities include:**\n\n*   **Data Engineering:** Leading and building data source integrations (APIs, MongoDB, MySQL), setting up and maintaining data platform infrastructure, implementing CI/CD and IaC, orchestrating data pipelines (e.g., Airflow), and introducing data product principles.\n*   **Analytics Engineering:** Designing and building robust data models using DBT, SQL, and Python to support business processes, ensuring data governance and trust, and contributing to analytical projects.\n\n**They are looking for someone with:**\n\n*   Experience in both Data Engineering and Analytics Engineering.\n*   Proficiency in building modern data platforms with GCP and Snowflake.\n*   Skills in data modeling (DBT, SQL), programming (Python, Java, or Go), CI/CD, IaC, and data orchestration.\n*   A technical or analytical university degree.\n*   Strong collaboration, communication skills, an agile mindset, and a drive to learn.\n*   Based in Stockholm and open to hybrid work (3 days in the office).\n*   Experience with Docker, Kubernetes, and streaming data is a plus.\n\n**Instabee offers** a chance to revolutionize logistics, a modern "sky-high" office (puppy-friendly), tech events, games, flexible hours, parental pay, and a birthday off, all within a company committed to diversity and inclusion.'

# %%
df["text"][0]
# Out:
# "About the team\n\nThe Data Platform team is newly formed and it will have two main roles in play, Data Engineer and Analytics Engineer. We have already developed a comprehensive way of working for ourselves and our stakeholders and built our solutions on a modern data stack using FiveTran, Python, DBT, GCP and Snowflake for data ingestion, storage and modeling with Tableau as our primary data visualization product.\n\n\nWhat you will be doing\n\nWithin the Data Platform team, you will get the chance to shape how Instabee builds its data platform which is serving many stakeholders in the organization and enables us to make better decisions. The data platform is a key asset that we use for multiple data processing purposes; while traditional BI is one use case we deploy, we also service data science investigations and create endpoints for our technology teams to use in our products and services.\n\nAs a Data Engineer you will take the lead on setting integration patterns from sources, as well as building and migrating source integrations for the data platform. You will also be part of the team setting up and maintaining data platform infrastructure. Additionally, you will be involved in initiatives to introduce data product principles such as discoverability and trustworthiness.\n\nWhy a Data Engineer with interest in Analytics Engineering\n\nAs a Data Engineer, you will have experience in:\n\nBuilding a modern data platform on GCP and Snowflake\n\nCreating data platform design patterns and then implementing them\n\nIntegrating data from sources such as APIs, MongoDB, MySQL\n\nSetting up CI/CD pipelines and employing IaC for infrastructure\n\nOrchestrating data pipelines with Airflow or similar\n\nModeling data with DBT and SQL, programming with Python (or Java or Go)\n\nNot required, but a big plus if you have experience with Docker and Kubernetes, as well as working with streaming data\n\n\n\nWith your interest and experience in Analytics Engineering, you will cover:\n\nDesigning and building data models that support business processes, ensuring governance and trust in data\n\nWorking with data transformation and modelling techniques using DBT with SQL and Python\n\nContributing to analytical projects to help answer a hypothesis or solve an idea a stakeholder might have\n\n\nWe think you are a person who...\n\nHas experience in both Data Engineering and Analytics Engineering\n\nHas a university degree in a technical or analytical field (e.g. Mathematics, Computer Science, Physics)\n\nThrives on challenges and is driven to learn new things, staying up to date with advances in the data field\n\nEnjoys collaborating with business stakeholders and acts as a bridge between business, data, and tech\n\nIs skilled at visualizing and communicating findings effectively to a wider audience\n\nPrefers to work with agile methods\n\nIs based in Stockholm and open to hybrid work (3 days from the office)\n\n\n\nWhat we offer\n\nThe chance to be part of something truly amazing and revolutionizing the logistics industry with new product offerings and exemplary service is what excites every employee working here today and we are still just getting started!\n\nIf you’ve read this far there is clearly nothing stopping you from clicking the apply button.\n\nWe look forward to meeting you\n\n\nOf course, we have all the necessary and standard benefits in place, but in addition to this, we can also offer:\n\n🌇 Sky-High Office: Modern and newly renovated with a 360-degree view around Stockholm.\n🐶 Puppy Friendly: Bring your dog to work - we've got a whole floor for our furry friends!\n🥐 Wednesdays Tech Breakfasts: Fuel your midweek with tech talks and tasty bites.\n👾 Tech Demos: Dive into the latest innovations with our regular tech showcases.\n💻 Modern Tech Stack: Work with cutting-edge technology every day.\n🏓 Fun & Games: Ping pong, Shuffleboard, Foosball, and even a Karaoke Room for your leisure time.\n⏰ Flexible Hours: Hybrid setup with working  ...

# %%
for summary_text in df["summary"]:
    print(summary_text)
    print("-" * 60)
# Out:
# This job ad is for a **Data Engineer with an interest in Analytics Engineering** at **Instabee**, a rapidly growing European last-mile delivery company (formed by Budbee and Instabox).
#
# The role is within a newly formed Data Platform team, tasked with building and shaping a modern data platform on GCP and Snowflake, utilizing tools like Fivetran, Python, DBT, and Tableau. This is a hybrid role, serving stakeholders across BI, data science, and product teams.
#
# **Key responsibilities include:**
#
# *   **Data Engineering:** Leading and building data source integrations (APIs, MongoDB, MySQL), setting up and maintaining data platform infrastructure, implementing CI/CD and IaC, orchestrating data pipelines (e.g., Airflow), and introducing data product principles.
# *   **Analytics Engineering:** Designing and building robust data models using DBT, SQL, and Python to support business processes, ensuring data governance and trust, and contributing to analytical projects.
#
# **They are looking for someone with:**
#
# *   Experience in both Data Engineering and Analytics Engineering.
# *   Proficiency in building modern data platforms with GCP and Snowflake.
# *   Skills in data modeling (DBT, SQL), programming (Python, Java, or Go), CI/CD, IaC, and data orchestration.
# *   A technical or analytical university degree.
# *   Strong collaboration, communication skills, an agile mindset, and a drive to learn.
# *   Based in Stockholm and open to hybrid work (3 days in the office).
# *   Experience with Docker, Kubernetes, and streaming data is a plus.
#
# **Instabee offers** a chance to revolutionize logistics, a modern "sky-high" office (puppy-friendly), tech events, games, flexible hours, parental pay, and a birthday off, all within a company committed to diversity and inclusion.
# ------------------------------------------------------------
# This job ad is for an **Engineering Operations Technician** at **Amazon Web Services (AWS)**, located primarily in **Vasteras, Sweden**, with potential for work at other Swedish data centers.
#
# The role is crucial for maintaining the **availability and reliability (targeting 99.999% uptime)** of mission-critical data center infrastructure. The technician will be responsible for the **operation, maintenance, and monitoring** of various facility systems, including electrical, mechanical, HVAC, and fire/life safety equipment.
#
# Key tasks involve:
# *   Troubleshooting system incidents.
# *   Assisting contractors with equipment deployment (e.g., rack building, cabling).
# *   Performing site walkthroughs and acting as a first responder to critical events.
# *   Monitoring alarms, coordinating vendor works, and supporting other teams.
# *   Participating in knowledge sharing and training.
#
# **Required qualifications** include at least **2 years of relevant experience** in electrical, mechanical, and/or controls (degree/trade preferred), an ability to prioritize in a fast-paced environment, a valid EU driving license, and availability for **24x7 shift rotations**. Preferred qualifications include professional certifications and heavy industry or data center experience with knowledge of relevant systems (electrical principles, HVAC, generators).
#
# AWS emphasizes a **diverse, inclusive culture** with opportunities for mentorship and career growth, valuing work-life harmony and encouraging applications from varied backgrounds.
# ------------------------------------------------------------
# NOBA Bank Group is seeking an **Engineering Manager** in **Stockholm** to lead a team of 5 Software Engineers. This team is responsible for customer onboarding solutions for the Nordax brand, specializing in secure loans.
#
# The role involves a blend of **hands-on technical work** (full-stack development, web services, system usability) and **leadership responsibilities**, including mentoring and coaching the team, driving daily deliveries, ensuring business objectives are met, providing technical guidance, improving development processes, and contributing to recruitment and cross-team initiatives.
#
# **Required qualifications** include:
# *   7+ years in C#/.NET/.NET Core software development.
# *   3+ years with modern JavaScript frameworks (preferably React).
# *   2+ years of formal leadership experience.
# *   Strong proficiency in Microsoft's development stack, lifecycle tools, and SQL.
# *   Experience in hiring, goal-setting, coaching, and performance reviews.
# *   Fluency in English.
#
# **Desired experience** includes public cloud platforms (Azure), TDD, CI/CD, Scrum Master responsibilities, and Swedish fluency.
#
# NOBA offers a culture of freedom with responsibility, career development, coaching leadership, and a caring, diverse, and "bubbly" work environment.
# ------------------------------------------------------------
# Tiohundra AB in Norrtälje is seeking a full-time, permanent (or potentially fixed-term) **Legitimized Physiotherapist (Fysioterapeut/Sjukgymnast)** to join their HSL-team within LSS (Support for People with Certain Functional Disabilities).
#
# The role involves working with individuals with functional disabilities, focusing on rehabilitation and bashabilitation. Duties include assessing functional ability, initiating treatment and training, prescribing assistive devices, and instructing/supporting LSS staff in a rehabilitative approach. Work is independent but also collaborative within a multidisciplinary team (with occupational therapists and nurses).
#
# Applicants must be a **legitimized physiotherapist** and possess a **Class B driving license with driving experience** as travel within Norrtälje is required. Experience with functional variations is a merit. Key personal qualities include strong communication, adaptability, collaboration skills, a patient-centered approach, and an interest in working with people with multiple functional disabilities.
#
# The position is full-time, Monday-Friday (daytime), and offers a 5000 SEK annual wellness allowance. The application deadline is **December 14th**.
# ------------------------------------------------------------

# %% [markdown]
# ##c)

# %%
def converttxt_tomd(df):

    dir_folder = Path("../data")

    for row in df.iterrows():
        md_filename = row["filename"].replace(".txt", ".md")
        md_path = dir_folder / md_filename
        
        content = f"# {row['filename']}\n\n"
        content += f"##-----------------Summarized ad----------------------\n\n"
        content += f"####  {row['summary']}  \n\n"
        content += f"##-----------------Main text----------------------\n\n"
        content += f"#### {row['text']}\n\n"
        content += f"---------------------------------------\n\n"
        
        
        md_path.write_text(content, encoding="utf-8")

# %% [markdown]
# ##d)

# %%
summaries = summarize_ads(df)
summaries
# Out:
#    filename                                               text  \
# 0  ads1.txt  About the team\n\nThe Data Platform team is ne...
# 1  ads2.txt  Engineering Operations Technician , Data Cente...
# 2  ads3.txt  At NOBA Bank Group, we are unlocking new possi...
# 3  ads4.txt  Fysioterapeut/sjukgymnast till HSL-team inom L...
#
#                                              summary
# 0  This job ad from **Instabee** (a rapidly growi...
# 1  This job ad is for an **Engineering Operations...
# 2  This is an exciting opportunity at **NOBA Bank...
# 3  This is an advertisement for a **full-time (10...

# %% [markdown]
# #1)

# %% [markdown]
# ##a)

# %%
from pydantic import BaseModel

class Person(BaseModel):
    name: str
    age: int
    country_of_birth: str
    
    
    
    
person1 = Person(name = "Luca", age = 34, country_of_birth = "Italy")

person1
# Out:
# Person(name='Luca', age=34, country_of_birth='Italy')

# %%
person2 = Person(name = 3, age = "34", country_of_birth = "Italy")

print(person2)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 person2 = Person(name = 3, age = "34", country_of_birth = "Italy")
#       3 print(person2)
#
# File c:\Users\eriku\Desktop\DataenginerSTI2024-2026\Github\AIgeneering_four_week_course\.venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for Person
# name
#   Input should be a valid string [type=string_type, input_value=3, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type

# %%
from pydantic import BaseModel, EmailStr

class Person(BaseModel):
    name: str
    age: int
    country_of_birth: str
    email: EmailStr
    favourite_pet: str
    
    
    
    
person1 = Person(email = "lucatoni@hotmail.com", name = "Luca", age = 34, country_of_birth = "Italy", favourite_pet= "pig")

person1
# Out:
# Person(name='Luca', age=34, country_of_birth='Italy', email='lucatoni@hotmail.com', favourite_pet='pig')

# %%
person2 = Person(email = "lucatoni", name = "Luca", age = 34, country_of_birth = "Italy", favourite_pet= "pig")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 person2 = Person(email = "lucatoni", name = "Luca", age = 34, country_of_birth = "Italy", favourite_pet= "pig")
#
# File c:\Users\eriku\Desktop\DataenginerSTI2024-2026\Github\AIgeneering_four_week_course\.venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for Person
# email
#   value is not a valid email address: An email address must have an @-sign. [type=value_error, input_value='lucatoni', input_type=str]

# %%
person3 = Person(email = "lucatoni@hotmail.com", name = "Luca", age = 34, country_of_birth = "Italy", favourite_pet= 60)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 person3 = Person(email = "lucatoni@hotmail.com", name = "Luca", age = 34, country_of_birth = "Italy", favourite_pet= 60)
#
# File c:\Users\eriku\Desktop\DataenginerSTI2024-2026\Github\AIgeneering_four_week_course\.venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for Person
# favourite_pet
#   Input should be a valid string [type=string_type, input_value=60, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.12/v/string_type

# %% [markdown]
# ##c)

# %%
class Person:
    def __init__(self, name: str, age: int,  country_of_birth: str) -> None:
        self.name = name
        self.age = age
        self.country_of_birth = country_of_birth

        
person1 = Person(name = "Luca", age = 34, country_of_birth = "Italy")

person1

# %%
person1.name, person1.age
# Out:
# ('Luca', 34)

# %% [markdown]
# #1)

# %%
import requests

headers = {"Accept": "application/json"}
response = requests.get("https://icanhazdadjoke.com/", headers=headers)

print(response.json())
# Out:
# {'id': '5EBlOKBQSvc', 'joke': 'Why did the banana go to the doctor? He was not "peeling" well.', 'status': 200}

# %% [markdown]
# ##a)

# %%
class Jokes(BaseModel):
    id: str
    joke: str
    status: int
    
 
joke1 = Jokes(id = "kgkg#", joke = "haha", status = 1)
joke1
# Out:
# Jokes(id='kgkg#', joke='haha', status=1)

# %% [markdown]
# ##b)

# %%
import requests

def get_dad_jokes() -> Jokes:
    headers = {"Accept": "application/json"}
    response = requests.get("https://icanhazdadjoke.com/", headers=headers)
    data = (response.json())
    dad_joke = Jokes(**data)
    
    return dad_joke


# dad_joke = get_dad_jokes()

joke2 = get_dad_jokes()

# %%
print(type(joke2))
print(joke2.id)
print(joke2.joke)
print(joke2.status)
# Out:
# <class '__main__.Jokes'>
# CdUnOKeiqzd
# which flower is most fierce? Dandelion
# 200

# %% [markdown]
# ##c)

# %%
from pydantic import computed_field

class Jokes(BaseModel):
    id: str
    joke: str
    status: int
    
    
    @computed_field
    @property
    def words_in_joke(self) -> int:
        """returns number of words in the joke"""
        return len(self.joke.split())

# %%
joke2.words_in_joke
# Out:
# 6

# %% [markdown]
# ##d)

# %%
import time

ten_jokes = []


for _ in range(10):
    joke = get_dad_jokes()
    ten_jokes.append(joke)
    time.sleep(5)

# %%
print(ten_jokes)
# Out:
# [Jokes(id='VKexkV0LeFd', joke="I was in an 80's band called the prevention. We were better than the cure.", status=200, words_in_joke=15), Jokes(id='CQSKeaFIBsc', joke='What does a female snake use for support? A co-Bra!', status=200, words_in_joke=10), Jokes(id='IeiyIRSnbxc', joke="I applied to be a doorman but didn't get the job due to lack of experience. That surprised me, I thought it was an entry level position.", status=200, words_in_joke=27), Jokes(id='dx5ojVK61wc', joke='What do you get hanging from Apple trees? Sore arms.', status=200, words_in_joke=10), Jokes(id='NCAIYLeNe', joke='I fear for the calendar, its days are numbered.\n', status=200, words_in_joke=9), Jokes(id='xHQucUvszd', joke='To the guy who invented zero... thanks for nothing.', status=200, words_in_joke=9), Jokes(id='xkGB5oWSKmb', joke='Did you hear about the new restaurant on the moon? The food is great, but there’s just no atmosphere.', status=200, words_in_joke=19), Jokes(id='YvkV8xXnjyd', joke='Why did the cowboy have a weiner dog? Somebody told him to get a long little doggy.', status=200, words_in_joke=17), Jokes(id='5h399pWLmyd', joke="What did the beaver say to the tree? It's been nice gnawing you.", status=200, words_in_joke=13), Jokes(id='H6EY0Dljiyd', joke='I always wanted to look into why I procrastinate, but I keep putting it off. ', status=200, words_in_joke=15)]

# %% [markdown]
# #3

# %% [markdown]
# ##a, b)

# %%
from pathlib import Path

data_dir = Path("exams")
files = sorted(data_dir.glob("te*.txt"))

student_papers = []

for path in files:
    text = path.read_text(encoding="utf-8")
    student_papers.append(
        {
          "filename": path.name,
          "text": text,
        }
    )
    

df = pd.DataFrame(student_papers)
print(df)
# Out:
#     filename                                               text
# 0  text1.txt  Inför allas blickar En av de större andledning...
# 1  text2.txt  Inför allas blickar Att ha muntliga presentati...

# %%
from google import genai

client = genai.Client()

def grade_texts(df, model="gemini-2.5-flash"):
    def get_summary(ad_text):
        response = client.models.generate_content(
            model=model,
            contents=f"Can you grade this text:{ad_text}"
        )
        return response.text
    
    df["grade"] = df["text"].apply(get_summary)
    return df

# Använd den
df = grade_texts(df)

print(df.loc[0, "grade"])
# Out:
# Okay, let's grade this text. I'll break it down into different categories.
#
# **Overall Impression:**
# The text is clear, personal, and well-structured in its argumentation, combining personal experience with external scientific reference. The message comes across effectively. However, it contains a significant number of grammatical, spelling, and stylistic errors that detract from its quality.
#
# ---
#
# **Detailed Breakdown:**
#
# **1. Content and Structure (Grade: B)**
# *   **Strengths:**
#     *   Clear topic: fear of public speaking (talrädsla).
#     *   Good flow: starts with personal experience, offers a potential solution, incorporates external research (Letmark), and concludes with further personal insights and advice.
#     *   The link to evolutionary explanations and social hierarchies is relevant and interesting.
#     *   The conclusion about speaking from the heart and the role of self-confidence is a strong point.
# *   **Weaknesses:**
#     *   The transition between "man" (impersonal) and "du" (you) is a bit inconsistent. While sometimes acceptable in informal texts, more consistency would improve flow.
#     *   The ending sentence is a bit clunky grammatically (see "Grammar" section).
#
# **2. Grammar and Syntax (Grade: D)**
# *   **Strengths:**
#     *   Most sentences are understandable despite errors.
# *   **Weaknesses (Significant):**
#     *   **Pronoun Errors ("de" vs. "dem"):** "dem ska tycka illa om en" should be "de ska tycka illa om en". "dom som har lite sämre själv förtroende" should be "de som har lite sämre självförtroende". This is a very common but fundamental error in Swedish.
#     *   **Verb Agreement/Participle:** "utstöt från gruppen" should be "utstött ur/från gruppen".
#     *   **Double Negative:** "utan att inte veta vad du ska prata om" is a double negative that changes the meaning. It should likely be "utan att behöva fundera på vad du ska prata om" or simply "utan att tappa tråden".
#     *   **Confusing Sentence Structure:** The last sentence "dom som har lite sämre själv förtroende blir du väldigt osäker på vad du säger och vågar inte argumentera om din åsikt" is grammatically incorrect. It mixes subjects. It should probably be: "De som har lite sämre självförtroende *blir ofta* osäkra på vad *de* säger och vågar inte argumentera om *sin* åsikt."
#
# **3. Spelling (Grade: D)**
# *   **Strengths:**
#     *   Most words are spelled correctly.
# *   **Weaknesses (Frequent):**
#     *   **Compound Words:** This is the most common and persistent error. Swedish often combines words into single units.
#         *   "andledningarna" should be "anledningarna" (minor misspelling)
#         *   "tal rädd" should be "talrädd"
#         *   "klass rummet" should be "klassrummet"
#         *   "jobb skäl" should be "jobbskäl"
#         *   "själv förtroende" should be "självförtroende" (repeatedly)
#     *   **Idiom:** "gör sig vann med" should be "gör sig van vid".
#
# **4. Vocabulary and Style (Grade: C)**
# *   **Strengths:**
#     *   Vocabulary is appropriate for the informal, reflective tone.
#     *   The language feels natural and personal.
#     *   Expressions like "sitter nära ditt hjärta" are good.
# *   **Weaknesses:**
#     *   Some phrasing is a bit colloquial or could be more precise/formal, e.g., "folket som lyssnar på" could be "publiken" or "åhörarna". "sitter och tittar på en" could be simply "tittar på en". "på något vis" is a bit informal.
#
# **5. Punctuation (Grade: B)**
# *   **Strengths:**
#     *   Generally correct use of periods and commas for basic sentence structure.
#
# ---
#
# **Final Grade: C- (Godkänt med tydliga brister / Passed with clear deficiencies)**
#
# **Summary:**
# The text successfully conveys its message and is well-structured regarding content. However, the numerous and recurring errors in grammar (especially "de/dem" and the problematic final sentence) and spelling (especially compound words) significantly hinder its quality and make it less professional. With some focused editing on these linguistic aspects, it could easily achieve a much higher grade.
#
# **Recommendations for Improvement:**
# 1.  **Compound Words:** Be very mindful of combining words in Swedish (e.g., *klassrummet*, *självförtroende*, *jobbskäl*, *talrädd*).
# 2.  **"De" vs. "Dem":** Remember "de" for the subject (who is doing the action) and "dem" for the object (who is receiving the action). A common trick: if you can replace it with "they" use "de," if "them" use "dem."
# 3.  **Sentence Structure:** Review complex sentences to ensure subject-verb agreement and clear pronoun reference. Avoid double negatives.
# 4.  **Proofread Carefully:** Read through your text slowly, specifically looking for common errors. Reading it aloud can often help identify awkward phrasing or grammatical mistakes.

# %% [markdown]
# ##c)

# %%
from google import genai

client = genai.Client()

def grade_texts(df, model="gemini-2.5-flash"):
    def get_summary(ad_text):
        response = client.models.generate_content(
            model=model,
            contents=f"""
            You are a teacher. Read this text and respond 
            ONLY as valid JSON with three keys: "proposed_grade", 
            "motivation", "improvements".
            
            Text: {ad_text}""",
            
            
        )
        return response.text
    
    df["grade"] = df["text"].apply(get_summary)
    return df

# Använd den
df = grade_texts(df)

print(df.loc[0, "grade"])
# Out:
# ```json
# {
#   "proposed_grade": "C",
#   "motivation": "Texten visar en god förståelse för ämnet talrädsla och kombinerar personliga reflektioner med en extern källa (Peter Letmark) på ett relevant sätt. Författaren lyfter fram både psykologiska och evolutionära aspekter av rädslan, samt föreslår konkreta strategier för att hantera den. Argumentationen är till stor del logisk och sammanhållen. Däremot dras texten ner av en betydande mängd språkliga brister, inklusive stavfel, grammatiska fel, inkonsekvens i pronomenanvändning och en del klumpiga formuleringar. Avsaknaden av styckeindelning gör den också något svårläst.",
#   "improvements": [
#     "**Språklig korrigering:** Gå noggrant igenom texten för att rätta till stavfel (t.ex. 'andledningar' -> 'anledningar', 'tal rädd' -> 'talrädd', 'klass rummet' -> 'klassrummet', 'själv förtroende' -> 'självförtroende', 'jobb skäl' -> 'jobbskäl', 'vann' -> 'van') och grammatiska fel (t.ex. dubbel negation i 'utan att inte veta').",
#     "**Konsekvens i pronomen:** Var konsekvent med 'man' eller 'du' genom hela texten för att undvika förvirring.",
#     "**Meningsbyggnad och flyt:** Förbättra meningsbyggnaden för att skapa ett bättre flyt i texten. Undvik upprepningar av ord ('sitter ett flertal människor som sitter').",
#     "**Styckeindelning:** Använd styckeindelning för att separera olika tankar och idéer. Detta skulle göra texten betydligt mer läsvänlig och överskådlig.",
#     "**Formuleringar:** Arbeta med att förfina formuleringar för att göra språket mer precist och akademiskt där det behövs (t.ex. 'folket som lyssnar på' kan förbättras till 'åhörarna' eller 'de som lyssnar')."
#   ]
# }
# ```

# %% [markdown]
# ##d)

# %%
class grade(BaseModel):
    
    proposed_grade: str
    motivation: str
    improvments: str
# Out:
# filename                                            text1.txt
# text        Inför allas blickar En av de större andledning...
# grade       ```json\n{\n  "proposed_grade": "D",\n  "motiv...
# Name: 0, dtype: object

# %%
first_student = grade_texts(df)
# Out:
#     filename                                               text  \
# 0  text1.txt  Inför allas blickar En av de större andledning...
# 1  text2.txt  Inför allas blickar Att ha muntliga presentati...
#
#                                                grade
# 0  ```json\n{\n  "proposed_grade": "C",\n  "motiv...
# 1  ```json\n{\n  "proposed_grade": "D",\n  "motiv...

# %%
first_student_deserialized = first_student.model_dump_json()  
print(first_student_deserialized)

# print(first_student.proposed_grade)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19176\3351350861.py in ?()
# ----> 1 first_student_deserialized = first_student.model_dump_json()
#       2 print(first_student_deserialized)
#       3
#       4 # print(first_student.proposed_grade)
#
# c:\Users\eriku\Desktop\DataenginerSTI2024-2026\Github\AIgeneering_four_week_course\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'model_dump_json'
