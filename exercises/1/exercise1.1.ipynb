# %% [markdown]
# #Restaurant model

# %%
from pydantic import BaseModel, Field
from typing import Literal
from pydantic_ai import Agent

agent = Agent(model="google-gla:gemini-2.5-flash")

class Restaurant(BaseModel):
    name: str 
    type_of_food: str = Field(description="short description of the type of food the restaurant serves")
    price_level: Literal["Cheap", "Medium", "Exclusive"] = Field(
    description="Name price level of the restaurants into categories: 'Cheap', 'Medium', 'Exclusive'"
    )
    rating: int = Field(gt=0, lt=10, description="Rate the restaurants between 0-10")
    description: str = Field(description="describe the resturant with a short description")
    opening_hours: str = Field(description="Opening hours for the restaurant") 
    location: str = Field(description="The location and adress for the restuarant")  
    
    
restaurant_list = list[Restaurant]
    
    
result = await agent.run(
    "Create 10 different resturants that were located in Stockholm in the 1920's",
    output_type=restaurant_list,
)

result
# Out:
# AgentRunResult(output=[Restaurant(name='Gamla Stans Källare', type_of_food='Classic Swedish husmanskost', price_level='Medium', rating=8, description='A cozy cellar restaurant in Old Town serving traditional Swedish dishes.', opening_hours='Monday-Saturday: 12:00-22:00', location='Stortorget 1, Gamla Stan, Stockholm'), Restaurant(name='Strandboulevarden Café', type_of_food='Coffee, pastries, and light lunches', price_level='Cheap', rating=7, description='A charming café by the water, perfect for a fika with views.', opening_hours='Monday-Sunday: 09:00-18:00', location='Strandvägen 15, Östermalm, Stockholm'), Restaurant(name='Operakällaren', type_of_food='Fine dining, French and Swedish cuisine', price_level='Exclusive', rating=9, description='An opulent restaurant in the Royal Opera House, known for its grand hall and exquisite food.', opening_hours='Tuesday-Saturday: 18:00-00:00', location='Jakobs Torg 2, Norrmalm, Stockholm'), Restaurant(name='Södermalms Wärdshus', type_of_food='Hearty Swedish pub food', price_level='Cheap', rating=6, description='A local pub on Södermalm offering robust and affordable meals.', opening_hours='Monday-Friday: 11:00-23:00, Saturday: 12:00-23:00', location='Hornsgatan 45, Södermalm, Stockholm'), Restaurant(name='Berns Salonger', type_of_food='European cuisine, entertainment venue', price_level='Exclusive', rating=8, description='More than just a restaurant, Berns offered a sophisticated dining and entertainment experience.', opening_hours='Tuesday-Saturday: 19:00-01:00', location='Berzelii Park, Norrmalm, Stockholm'), Restaurant(name='Kungsträdgårdens Terrass', type_of_food='Seasonal outdoor dining, Swedish classics', price_level='Medium', rating=7, description='An open-air restaurant in Kungsträdgården, popular during warmer months.', opening_hours='May-September: 11:00-22:00 (weather permitting)', location='Kungsträdgården, Norrmalm, Stockholm'), Restaurant(name='Vasastans Matpalats', type_of_food='Home-style Swedish cooking, daily specials', price_level='Cheap', rating=6, description='A simple and friendly eatery in Vasastan, serving wholesome meals.', opening_hours='Monday-Friday: 11:00-20:00', location='Odengatan 30, Vasastan, Stockholm'), Restaurant(name='Diplomat Restaurang', type_of_food='Classic international cuisine', price_level='Exclusive', rating=8, description='An elegant restaurant within the Grand Hôtel, frequented by high society.', opening_hours='Monday-Saturday: 12:00-14:30, 18:00-22:30', location='Södra Blasieholmshamnen 8, Norrmalm, Stockholm'), Restaurant(name='Djurgårdsbrunns Wärdshus', type_of_food='Traditional Swedish dishes in a rural setting', price_level='Medium', rating=7, description='A picturesque inn on Djurgården, offering a peaceful escape with good food.', opening_hours='Tuesday-Sunday: 12:00-21:00', location='Djurgårdsbrunnsvägen 68, Djurgården, Stockholm'), Restaurant(name='Rådhuskällaren', type_of_food='Hearty Swedish lunch and dinner', price_level='Medium', rating=7, description='A bustling cellar restaurant near the City Hall, known for its traditional fare.', opening_hours='Monday-Saturday: 11:30-22:00', location='Hantverkargatan 1, Kungsholmen, Stockholm')])

# %%
from pprint import pprint

pprint(result.output)
# Out:
# [Restaurant(name='Gamla Stans Källare', type_of_food='Classic Swedish husmanskost', price_level='Medium', rating=8, description='A cozy cellar restaurant in Old Town serving traditional Swedish dishes.', opening_hours='Monday-Saturday: 12:00-22:00', location='Stortorget 1, Gamla Stan, Stockholm'),
#  Restaurant(name='Strandboulevarden Café', type_of_food='Coffee, pastries, and light lunches', price_level='Cheap', rating=7, description='A charming café by the water, perfect for a fika with views.', opening_hours='Monday-Sunday: 09:00-18:00', location='Strandvägen 15, Östermalm, Stockholm'),
#  Restaurant(name='Operakällaren', type_of_food='Fine dining, French and Swedish cuisine', price_level='Exclusive', rating=9, description='An opulent restaurant in the Royal Opera House, known for its grand hall and exquisite food.', opening_hours='Tuesday-Saturday: 18:00-00:00', location='Jakobs Torg 2, Norrmalm, Stockholm'),
#  Restaurant(name='Södermalms Wärdshus', type_of_food='Hearty Swedish pub food', price_level='Cheap', rating=6, description='A local pub on Södermalm offering robust and affordable meals.', opening_hours='Monday-Friday: 11:00-23:00, Saturday: 12:00-23:00', location='Hornsgatan 45, Södermalm, Stockholm'),
#  Restaurant(name='Berns Salonger', type_of_food='European cuisine, entertainment venue', price_level='Exclusive', rating=8, description='More than just a restaurant, Berns offered a sophisticated dining and entertainment experience.', opening_hours='Tuesday-Saturday: 19:00-01:00', location='Berzelii Park, Norrmalm, Stockholm'),
#  Restaurant(name='Kungsträdgårdens Terrass', type_of_food='Seasonal outdoor dining, Swedish classics', price_level='Medium', rating=7, description='An open-air restaurant in Kungsträdgården, popular during warmer months.', opening_hours='May-September: 11:00-22:00 (weather permitting)', location='Kungsträdgården, Norrmalm, Stockholm'),
#  Restaurant(name='Vasastans Matpalats', type_of_food='Home-style Swedish cooking, daily specials', price_level='Cheap', rating=6, description='A simple and friendly eatery in Vasastan, serving wholesome meals.', opening_hours='Monday-Friday: 11:00-20:00', location='Odengatan 30, Vasastan, Stockholm'),
#  Restaurant(name='Diplomat Restaurang', type_of_food='Classic international cuisine', price_level='Exclusive', rating=8, description='An elegant restaurant within the Grand Hôtel, frequented by high society.', opening_hours='Monday-Saturday: 12:00-14:30, 18:00-22:30', location='Södra Blasieholmshamnen 8, Norrmalm, Stockholm'),
#  Restaurant(name='Djurgårdsbrunns Wärdshus', type_of_food='Traditional Swedish dishes in a rural setting', price_level='Medium', rating=7, description='A picturesque inn on Djurgården, offering a peaceful escape with good food.', opening_hours='Tuesday-Sunday: 12:00-21:00', location='Djurgårdsbrunnsvägen 68, Djurgården, Stockholm'),
#  Restaurant(name='Rådhuskällaren', type_of_food='Hearty Swedish lunch and dinner', price_level='Medium', rating=7, description='A bustling cellar restaurant near the City Hall, known for its traditional fare.', opening_hours='Monday-Saturday: 11:30-22:00', location='Hantverkargatan 1, Kungsholmen, Stockholm')]
